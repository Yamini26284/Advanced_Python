# %%
print("Hello!",1,5,"radha, rani",sep='-') # seperated for values not commas.
# the separator will not appear in your output unless you pass at least two separate values.
print(sep="-")
# Out:
# Hello!-1-5-radha, rani

# %%
print("""hi,
there""")

print('''hello,
      voila''')
# Out:
# hi,
# there
# hello,
#       voila

# %%
# Escape Characters
print("hello there, this is 'Amazing'")
print('i know i\'m exagerating')
# Out:
# hello there, this is 'Amazing'
# i know i'm exagerating

# %%
my_var = 'Priya'
my_num = 11
print(my_var + " is born on " + str(my_num)) 

'''
concatenation is the operation of joining two sequences end-to-end. While we use it most often with strings in Python, it actually works on any sequence type that is of the same kind. concatenation cannot happen between two diff data types'''

new = 10
print(my_num + new)
print(str(my_num) + str(new))
# Out:
# Priya is born on 11
# 21
# 1110

# %%
''' Multiple Assignment - assigning mutliple variables together in a single line '''
x,y,z = 2,9,1
print(x,y,z)
# Out:
# 2 9 1

# %%
# Backslash allows us to run the next line in the same  line.
x = 10+20\
+50+10
y = (20+20
+50+10)
print(x,y)
# Out:
# 90 100

# %%
a = 10
b = 10
print(str(a)+str(b))
print(int(a)+int(b))
# Out:
# 1010
# 20
